# %%
import nltk, re, pprint
from nltk import word_tokenize

# %%
f = open('nar.txt','r')
raw = f.read()

# %%
raw.__class__.__name__
# Out:
# 'str'

# %%
f.__class__.__name__
# Out:
# 'TextIOWrapper'

# %%
raw[:100]
# Out:
# "yesterday at night (.) there's an animal in a jar .\nthere's a boy and a little dog .\n<they were> [//"

# %%
raw.replace('\n',' ').split()
# Out:
# ['yesterday',
#  'at',
#  'night',
#  '(.)',
#  "there's",
#  'an',
#  'animal',
#  'in',
#  'a',
#  'jar',
#  '.',
#  "there's",
#  'a',
#  'boy',
#  'and',
#  'a',
#  'little',
#  'dog',
#  '.',
#  '<they',
#  'were>',
#  '[//]',
#  'he',
#  'goes',
#  'to',
#  'bed',
#  '.',
#  'he',
#  'wakes',
#  'up',
#  'in',
#  'the',
#  'morning',
#  '.',
#  'he',
#  'found',
#  'out',
#  'that',
#  'an',
#  'animal',
#  "wasn't",
#  'in',
#  'the',
#  'jar',
#  '.',
#  'so',
#  '<the',
#  'dog',
#  'went>',
#  '[//]',
#  'the',
#  'dog',
#  'put',
#  'his',
#  'head',
#  'in',
#  'the',
#  'jar',
#  '.',
#  'and',
#  'he',
#  'fell',
#  'out',
#  'into',
#  '&er',
#  'the',
#  'window',
#  '.',
#  'and',
#  'the',
#  'boy',
#  'got',
#  'him',
#  '.',
#  'and',
#  'he',
#  'smashed',
#  'the',
#  'jar',
#  '.',
#  'the',
#  'boy',
#  'and',
#  'the',
#  'dog',
#  'were',
#  'looking',
#  'for',
#  'the',
#  'animal',
#  '.',
#  'and',
#  '&er',
#  '<they',
#  'see>',
#  '[//]',
#  'they',
# ...

# %%
raw
# Out:
# 'yesterday at night (.) there\'s an animal in a jar .\nthere\'s a boy and a little dog .\n<they were> [//] he goes to bed .\nhe wakes up in the morning .\nhe found out that an animal wasn\'t in the jar .\nso <the dog went> [//] the dog put his head in the jar .\nand he fell out into &er the window .\nand the boy got him .\nand he smashed the jar .\nthe boy and the dog were looking for the animal .\nand &er <they see> [//] they saw a bee [/] &er bees\' &um hatch [*]\n&um <they look in> [/-] the boy looks in the hole .\nand the dog starts barking at the bees .\nout_of the hole was [*] a little rat .\nthey kept on looking .\nthe dog kept &um barking and barking where the bees\' hatch [*] &um\nand the dog was still barking .\nthe boy was looking in the &um tree for the animal .\nthe [/] the dog was running away from the bees .\nand the boy fell out_of the tree .\n<a xxx> [//] a boy heard &um an owl .\nand he were [*] looking behind the rocks .\nbut a little deer grabbed hold of him in_be
# ...
